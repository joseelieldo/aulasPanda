# %%
#importar Bibliotecas

import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn')

#Formatar decimais
pd.options.display.float_format='{:20,.2f}'.format

# %%
#Carregar Arquivo
#Permite Escolher O Arquivo quando executa a celula

from google.colab import files
arq=files.upload()
# Out:
#      <input type="file" id="files-b202b855-b2af-422c-889a-d502e9ae54c3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b202b855-b2af-422c-889a-d502e9ae54c3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving AdventureWorks.xlsx to AdventureWorks.xlsx

# %%
#Criar DataFrame

df=pd.read_excel("AdventureWorks.xlsx")

# %%
# Visualiar as primeiras Linhas
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ...            Marca   Classe  Cor
# 0 2008-05-09 2008-05-29      199  ...  Adventure Works  Regular  Red
# 1 2008-05-12 2008-05-17      306  ...  Adventure Works  Regular  Red
# 2 2008-05-14 2008-05-20      306  ...  Adventure Works  Regular  Red
# 3 2008-05-21 2008-05-27      306  ...  Adventure Works  Regular  Red
# 4 2008-06-20 2008-06-27      306  ...  Adventure Works  Regular  Red
#
# [5 rows x 16 columns]

# %%
# Visualiar Quantidade de Linhas
df.shape
# Out:
# (904, 16)

# %%
# Visualiar datatypes
df.dtypes
# Out:
# Data Venda        datetime64[ns]
# Data Envio        datetime64[ns]
# ID Loja                    int64
# ID Produto                 int64
# ID Cliente                 int64
# No. Venda                 object
# Custo Unitário           float64
# Preço Unitário           float64
# Quantidade                 int64
# Valor Desconto           float64
# Valor Venda              float64
# Produto                   object
# Fabricante                object
# Marca                     object
# Classe                    object
# Cor                       object
# dtype: object

# %%
#Receita Total
df['Valor Venda'].sum()
# Out:
# 5984606.1426

# %%
#Criar Coluna Custo
df['Custo']=df['Custo Unitário'].mul(df['Quantidade'])

# %%
#Verificar nova coluna
df.head(3)
# Out:
#   Data Venda Data Envio  ID Loja  ...   Classe  Cor    Custo
# 0 2008-05-09 2008-05-29      199  ...  Regular  Red  2091.48
# 1 2008-05-12 2008-05-17      306  ...  Regular  Red  2091.48
# 2 2008-05-14 2008-05-20      306  ...  Regular  Red  2091.48
#
# [3 rows x 17 columns]

# %%
#Calcular Custo Total
round(df['Custo'].sum(),2)
# Out:
# 2486783.05

# %%
#Criar Coluna Lucro

df['Lucro']=df['Valor Venda']-df['Custo']

# %%
#Calcular Lucro Total
round(df['Lucro'].sum(),2)
# Out:
# 3497823.09

# %%
#Coluna Tempo de Envio
df['Tempo_Evnio']=(df['Data Envio']-df['Data Venda'])
df.head()
# Out:
#   Data Venda Data Envio  ID Loja  ID Produto  ...  Cor    Custo    Lucro  Tempo_Evnio
# 0 2008-05-09 2008-05-29      199         384  ...  Red  2091.48  2456.52      20 days
# 1 2008-05-12 2008-05-17      306         384  ...  Red  2091.48  2456.52       5 days
# 2 2008-05-14 2008-05-20      306         384  ...  Red  2091.48  2456.52       6 days
# 3 2008-05-21 2008-05-27      306         384  ...  Red  2091.48  2456.52       6 days
# 4 2008-06-20 2008-06-27      306         384  ...  Red  2091.48  2456.52       7 days
#
# [5 rows x 19 columns]

# %%
#Extraindo apenas os dias
df['Tempo_Evnio']=(df['Data Envio']-df['Data Venda']).dt.days

# %%
df['Tempo_Evnio'].dtypes
# Out:
# dtype('int64')

# %%
#Media de Tempo de Envio Por Marca
df.groupby('Marca')['Tempo_Evnio'].mean()
# Out:
# Marca
# Adventure Works    8.663866
# Contoso            8.470930
# Fabrikam           8.510121
# Name: Tempo_Evnio, dtype: float64

# %%
# Verificar Valores Nulos
df.isnull().sum()
# Out:
# Data Venda        0
# Data Envio        0
# ID Loja           0
# ID Produto        0
# ID Cliente        0
# No. Venda         0
# Custo Unitário    0
# Preço Unitário    0
# Quantidade        0
# Valor Desconto    0
# Valor Venda       0
# Produto           0
# Fabricante        0
# Marca             0
# Classe            0
# Cor               0
# Custo             0
# Lucro             0
# Tempo_Evnio       0
# dtype: int64

# %%
#Agrupar Lucro Por Ano e Por Marca

df.groupby([df['Data Venda'].dt.year,'Marca'])['Lucro'].sum()
# Out:
# Data Venda  Marca
# 2008        Adventure Works             306,641.16
#             Contoso                      56,416.00
#             Fabrikam                  1,557,020.55
# 2009        Adventure Works             405,395.08
#             Contoso                     138,258.95
#             Fabrikam                  1,034,091.35
# Name: Lucro, dtype: float64

# %%
#Reset Index

lucro_ano=df.groupby([df['Data Venda'].dt.year,'Marca'])['Lucro'].sum().reset_index()
lucro_ano
# Out:
#    Data Venda            Marca                Lucro
# 0        2008  Adventure Works           306,641.16
# 1        2008          Contoso            56,416.00
# 2        2008         Fabrikam         1,557,020.55
# 3        2009  Adventure Works           405,395.08
# 4        2009          Contoso           138,258.95
# 5        2009         Fabrikam         1,034,091.35

# %%
#Quantidade de Produtos Vendidos

df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=False)
# Out:
# Produto
# Headphone Adapter for Contoso Phone E130 Silver    25232
# Headphone Adapter for Contoso Phone E130 White     25008
# Adventure Works Laptop15.4W M1548 Black             1089
# Fabrikam Trendsetter 2/3'' 17mm X100 Grey           1087
# Adventure Works Laptop15.4W M1548 Red               1047
# Fabrikam Trendsetter 2/3'' 17mm X100 Black           926
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Black          884
# Fabrikam Trendsetter 1/3'' 8.5mm X200 Grey           845
# Fabrikam Trendsetter 1/3'' 8.5mm X200 White          789
# Name: Quantidade, dtype: int64

# %%
#Grafico Quantidade de Produtos Vendidos
df.groupby('Produto')['Quantidade'].sum().sort_values(ascending=True).plot.barh(title="Total de Produtos Vendidos")
plt.xlabel('Total')
plt.ylabel('Produto');

# %%
df.groupby(df['Data Venda'].dt.year)['Lucro'].sum().plot.bar(title='Lucro X Ano')
plt.xlabel('Ano')
plt.ylabel('Lucro');

# %%
#Filtrando pro Ano 2009
df_2009 = df[df["Data Venda"].dt.year == 2009]

# %%
df_2009.groupby(df_2009["Data Venda"].dt.month)["Lucro"].sum().plot(title="Lucro x Mês")
plt.xlabel("Mês")
plt.ylabel("Lucro");

# %%
#Lucro Por Marca
df_2009.groupby("Marca")["Lucro"].sum().plot.bar(title="Lucro x Marca")
plt.xlabel("Marca")
plt.ylabel("Lucro")
plt.xticks(rotation='horizontal');

# %%
#Lucro Por Classe
df_2009.groupby("Classe")["Lucro"].sum().plot.bar(title="Lucro x Classe")
plt.xlabel("Classe")
plt.ylabel("Lucro")
plt.xticks(rotation='horizontal')
# Out:
# (array([0, 1]), <a list of 2 Text major ticklabel objects>)

# %%
df['Tempo_Evnio'].describe()
# Out:
# count                 904.00
# mean                    8.54
# std                     3.06
# min                     4.00
# 25%                     6.00
# 50%                     9.00
# 75%                    11.00
# max                    20.00
# Name: Tempo_Evnio, dtype: float64

# %%
#Gafrico de Boxplot
plt.boxplot(df["Tempo_Evnio"]);

# %%
#Histograma"
plt.hist(df["Tempo_Evnio"]);

# %%
#Tempo mínimo de envio
df["Tempo_Evnio"].min()
# Out:
# 4

# %%
#Tempo Maximo de envio
df["Tempo_Evnio"].max()
# Out:
# 20

# %%
#Identificando o Outlier
df[df["Tempo_Evnio"] == 20]
# Out:
#   Data Venda Data Envio  ...                Lucro  Tempo_Evnio
# 0 2008-05-09 2008-05-29  ...             2,456.52           20
#
# [1 rows x 19 columns]
